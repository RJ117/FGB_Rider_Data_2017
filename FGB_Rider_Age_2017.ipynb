# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df =  pd.read_csv('C:/Users/RJ/Documents/FGB/2017-fordgobike-tripdata.csv')

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1         78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2         45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3         62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4         43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
#
#    start_station_id                                 start_station_name  \
# 0                74                              Laguna St at Hayes St
# 1               284  Yerba Buena Center for the Arts (Howard St at ...
# 2               245                             Downtown Berkeley BART
# 3                60                               8th St at Ringold St
# 4               239                      Bancroft Way at Telegraph Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
df.columns
# Out:
# Index(['duration_sec', 'start_time', 'end_time', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type',
#        'member_birth_year', 'member_gender'],
#       dtype='object')

# %%
df.groupby('user_type').describe()
# Out:
#              bike_id                                                        \
#                count         mean         std   min    25%     50%     75%
# user_type
# Customer    110470.0  1620.866398  956.626188  11.0  755.0  1657.0  2450.0
# Subscriber  409230.0  1686.480292  974.827223  10.0  797.0  1746.0  2538.0
#
#                    duration_sec                  ...      \
#                max        count         mean     ...
# user_type                                        ...
# Customer    3732.0     110470.0  2557.445786     ...
# Subscriber  3733.0     409230.0   705.310490     ...
#
#            start_station_latitude            start_station_longitude  \
#                               75%        max                   count
# user_type
# Customer                37.798014  37.880222                110470.0
# Subscriber              37.795001  37.880222                409230.0
#
#                                                                       \
# ...

# %% [markdown]
# <h1> Age </h1
# <br><br>
# Mean for age.

# %%
df.member_birth_year.mean()
# Out:
# 1980.4047872821682

# %%
df.groupby('duration_sec').member_birth_year.mean()
# Out:
# duration_sec
# 61       1984.686275
# 62       1982.057143
# 63       1983.666667
# 64       1980.823529
# 65       1981.964286
# 66       1982.980000
# 67       1982.300000
# 68       1981.666667
# 69       1981.756757
# 70       1982.613636
# 71       1983.515152
# 72       1982.696970
# 73       1982.820513
# 74       1982.830189
# 75       1983.408163
# 76       1983.348837
# 77       1979.323944
# 78       1981.887097
# 79       1982.562500
# 80       1982.977778
# 81       1983.179104
# 82       1982.661017
# 83       1981.701493
# 84       1983.192308
# 85       1983.898305
# 86       1982.152778
# 87       1981.393939
# 88       1982.666667
# 89       1981.029412
# 90       1981.756098
#             ...
# 84915            NaN
# 84999    1987.000000
# 85034    1968.000000
# 85036    1970.000000
# 85079    1970.000000
# 85091            NaN
# 85191    1982.000000
# 85218            NaN
# 85314    1960.000000
# 85366            NaN
# 85414            NaN
# 85491    1984.000000
# ...

# %%
df.groupby('member_birth_year').describe()
# Out:
#                    bike_id                                                    \
#                      count         mean          std    min      25%     50%
# member_birth_year
# 1886.0                 2.0   769.500000   959.543902   91.0   430.25   769.5
# 1900.0               142.0  1497.070423   937.259735   31.0   780.75  1295.5
# 1901.0                 4.0  1136.500000  1084.734530  155.0   548.00   861.0
# 1902.0               217.0  1654.566820   996.390098   62.0   760.00  1752.0
# 1907.0                 7.0  1811.142857   929.031293  233.0  1428.50  1667.0
# 1911.0                12.0  1879.833333  1400.621540  101.0   320.00  2055.0
# 1924.0                66.0  1878.742424   958.212620   26.0  1144.75  2168.5
# 1928.0                29.0  1645.551724   974.551127  195.0   674.00  2063.0
# 1933.0                41.0  1689.048780  1097.706494   99.0   586.00  1510.0
# 1934.0                34.0  1741.823529  1021.665262  135.0   803.00  1695.5
# ...

# %% [markdown]
# <h1> Average Riding Time</h1>

# %%
df.duration_sec.mean()
# Out:
# 1099.0095208774294

# %%
df.groupby('duration_sec').describe()
# Out:
#              bike_id                                                     \
#                count         mean          std     min      25%     50%
# duration_sec
# 61              58.0  1665.965517   943.104299    24.0   926.75  1830.0
# 62              42.0  1698.714286  1028.966265    75.0   762.50  1686.5
# 63              43.0  1931.069767   916.052904    51.0  1100.00  2129.0
# 64              40.0  1753.700000  1030.700986   161.0   658.25  1926.0
# 65              39.0  1520.974359   825.531806    58.0   799.50  1558.0
# 66              59.0  1417.288136  1062.541667    10.0   619.50  1195.0
# 67              46.0  1614.021739   995.054538    73.0   544.25  1664.5
# 68              43.0  1889.000000  1006.066007    86.0  1119.00  2046.0
# 69              43.0  1701.069767  1037.703609   120.0   643.00  1821.0
# 70              51.0  1408.411765   989.492277    22.0   663.50  1166.0
# 71              35.0  1588.371429   965.092805    63.0   779.50  1710.0
# ...

# %%
df.groupby('user_type').member_birth_year.mean()
# Out:
# user_type
# Customer      1983.614199
# Subscriber    1980.018038
# Name: member_birth_year, dtype: float64

# %%
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  519700.000000     519700.000000           519700.000000
# mean     1099.009521         95.034245               37.771653
# std      3444.146451         86.083078                0.086305
# min        61.000000          3.000000               37.317298
# 25%       382.000000         24.000000               37.773492
# 50%       596.000000         67.000000               37.783521
# 75%       938.000000        139.000000               37.795392
# max     86369.000000        340.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            519700.000000   519700.000000         519700.000000
# mean               -122.363927       92.184041             37.771844
# std                   0.105573       84.969491              0.086224
# min                -122.444293        3.000000             37.317298
# ...

# %%
df.stack().value_counts()
# Out:
# Subscriber                                                   409230
# Male                                                         348318
# Customer                                                     110470
# Female                                                        98621
# 15                                                            32433
# San Francisco Ferry Building (Harry Bridges Plaza)            32296
# 37.795392                                                     32296
# -122.394203                                                   32296
# 6                                                             30195
# 37.80477                                                      30195
# -122.40323400000001                                           30195
# The Embarcadero at Sansome St                                 30195
# 30                                                            30005
# 37.776598                                                     29924
# ...

# %%
df.hist(column='member_birth_year',by='member_gender', bins=75,figsize=(20,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016E49F3B4A8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016E4C8C3780>]], dtype=object)

# %%
df.hist(column='start_time',by='end_time', bins=75,figsize=(20,4))
